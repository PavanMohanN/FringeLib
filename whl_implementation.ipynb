# %% [markdown]
# `Created in Jul 2024`
#
# `@author: Pavan Mohan Neelamraju`
#
# `Affiliation: Indian Institute of Technology Madras`
#
# **Email**: npavanmohan3@gmail.com
#
# **Personal Website 🔴🔵**: [pavanmohann.github.io](https://pavanmohann.github.io/)
#
#
# ---

# %% [markdown]
# # Import your data

# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the image
img = cv2.imread('/content/drive/MyDrive/fringe correction/sample_images/synthetic_data/fringed/f12.png')

# Display the image using matplotlib
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# # Import the library
# Step 1: import fringelib
#
# Step 2: Use the required function
#
# - fringelib.frng_a: used for images requiring amplitude correction
#
# - fringelib.frng_p: used for images requiring phase correction
#
# Step 3: The output "result_p" (*in here*) should be visualized in **cmap='gray'** as both frng_a and frng_p produces the same.

# %%
# !pip install https://github.com/PavanMohanN/fringe_pack/raw/main/dist/fringe_pack-1.0-py3-none-any.whl
# !git clone https://github.com/PavanMohanN/fringe_pack.git
# Out:
# Cloning into 'fringe_pack'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 57 (delta 9), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (57/57), 19.44 KiB | 865.00 KiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd fringe_pack/src/fringe_pack
# Out:
# /content/fringe_pack/src/fringe_pack

# %%
import FringeLib

# %%
result_p = FringeLib.frng_p(img)

# %%
plt.imshow(result_p,cmap='gray')  # the result is always in gray scale for better visualization
plt.axis(False)
# Out:
# (-0.5, 383.5, 383.5, -0.5)
